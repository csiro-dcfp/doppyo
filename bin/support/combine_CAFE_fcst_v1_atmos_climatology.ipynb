# %% [markdown]
# # This notebook combines yearly CAFE v1 atmos daily climatologies in a single dataset

# %%
import pandas as pd
import xarray as xr
import numpy as np
from pylatte import utils
from ipywidgets import FloatProgress

# %%
# variables = ['lwf',   'shf',   'tau_x', 'tau_y', 't_ref', 'q_ref', 'u_ref', 'v_ref', 't_ref_min',
#              't_ref_max', 't_s',    'p_s', 'slp', 'h500', 'precip', 'lwf_dn_s', 'lwf_up_s', 'olwr', 
#              'swf_dn_s', 'swf_up_s', 'swf_up_toa', 'high_cld_amt', 'low_cld_amt', 'mid_cld_amt', 'tot_cld_amt']
variables = ['lwf',   'shf',   'tau_x', 'tau_y', 't_ref', 'q_ref', 'u_ref', 'v_ref', 'slp', 'h500']
variables = ['precip']
years = range(2003,2016)

# %%
var_list = []
for idx, variable in enumerate(variables):
    yr_list = []
    for year in years:
        fldrname = 'cafe.fcst.v1.atmos.' + str(variable) + '.' + str(year) + '.clim.nc'
        yr_list.append('/OSM/CBR/OA_DCFP/data/intermediate_products/pylatte_climatologies/' + fldrname)
    
    var_list.append(xr.open_mfdataset(yr_list,concat_dim='year').mean(dim='year'))

# %%
savename = 'cafe.fcst.v1.atmos_daily.1lev.2003010112_2021063012.clim.nc'
xr.merge(var_list).to_netcdf(path='/OSM/CBR/OA_DCFP/data/intermediate_products/pylatte_climatologies/' + savename,
                                  mode = 'w')

# %%
test1 = xr.open_dataset(base + 'cafe.fcst.v1.atmos.temp.2016.2.clim.nc')
test2 = xr.open_dataset(base + 'cafe.fcst.v1.atmos.temp.2015.1.clim.nc')

# %%
test1['sum'].isel(time=0,pfull=23).plot()

# %%
((test1['sum'] / test1['count']).isel(time=10,pfull=23) - (test2['sum'] / test1['count']).isel(time=10,pfull=23)).plot()

# %%
years=range(2002,2017)
months=range(1,13)
load_list = []
for year in years:
    for month in months:
        base = '/OSM/CBR/OA_DCFP/data/intermediate_products/pylatte_climatologies/tmp/'
        fldrname = 'cafe.fcst.v1.atmos.temp.' + str(year) + '.' + str(month) + '.clim.nc'
        try: 
            load_list.append(xr.open_mfdataset(base + fldrname))
            print(fldrname)
        except: pass
# Out:
# cafe.fcst.v1.atmos.temp.2002.2.clim.nc
# cafe.fcst.v1.atmos.temp.2002.3.clim.nc
# cafe.fcst.v1.atmos.temp.2002.4.clim.nc
# cafe.fcst.v1.atmos.temp.2002.5.clim.nc
# cafe.fcst.v1.atmos.temp.2002.6.clim.nc
# cafe.fcst.v1.atmos.temp.2002.7.clim.nc
# cafe.fcst.v1.atmos.temp.2002.8.clim.nc
# cafe.fcst.v1.atmos.temp.2002.9.clim.nc
# cafe.fcst.v1.atmos.temp.2002.10.clim.nc
# cafe.fcst.v1.atmos.temp.2002.11.clim.nc
# cafe.fcst.v1.atmos.temp.2002.12.clim.nc
# cafe.fcst.v1.atmos.temp.2003.1.clim.nc
# cafe.fcst.v1.atmos.temp.2003.2.clim.nc
# cafe.fcst.v1.atmos.temp.2003.3.clim.nc
# cafe.fcst.v1.atmos.temp.2003.4.clim.nc
# cafe.fcst.v1.atmos.temp.2003.5.clim.nc
# cafe.fcst.v1.atmos.temp.2003.6.clim.nc
# cafe.fcst.v1.atmos.temp.2003.7.clim.nc
# cafe.fcst.v1.atmos.temp.2003.8.clim.nc
# cafe.fcst.v1.atmos.temp.2003.9.clim.nc
# cafe.fcst.v1.atmos.temp.2003.10.clim.nc
# cafe.fcst.v1.atmos.temp.2003.11.clim.nc
# cafe.fcst.v1.atmos.temp.2003.12.clim.nc
# cafe.fcst.v1.atmos.temp.2004.1.clim.nc
# cafe.fcst.v1.atmos.temp.2004.2.clim.nc
# cafe.fcst.v1.atmos.temp.2004.3.clim.nc
# cafe.fcst.v1.atmos.temp.2004.4.clim.nc
# cafe.fcst.v1.atmos.temp.2004.5.clim.nc
# cafe.fcst.v1.atmos.temp.2004.6.clim.nc
# cafe.fcst.v1.atmos.temp.2004.7.clim.nc
# cafe.fcst.v1.atmos.temp.2004.8.clim.nc
# cafe.fcst.v1.atmos.temp.2004.9.clim.nc
# cafe.fcst.v1.atmos.temp.2004.10.clim.nc
# cafe.fcst.v1.atmos.temp.2004.11.clim.nc
# cafe.fcst.v1.atmos.temp.2004.12.clim.nc
# cafe.fcst.v1.atmos.temp.2005.1.clim.nc
# cafe.fcst.v1.atmos.temp.2005.2.clim.nc
# cafe.fcst.v1.atmos.temp.2005.3.clim.nc
# cafe.fcst.v1.atmos.temp.2005.4.clim.nc
# cafe.fcst.v1.atmos.temp.2005.5.clim.nc
# cafe.fcst.v1.atmos.temp.2005.6.clim.nc
# cafe.fcst.v1.atmos.temp.2005.7.clim.nc
# cafe.fcst.v1.atmos.temp.2005.8.clim.nc
# cafe.fcst.v1.atmos.temp.2005.9.clim.nc
# cafe.fcst.v1.atmos.temp.2005.10.clim.nc
# cafe.fcst.v1.atmos.temp.2005.11.clim.nc
# cafe.fcst.v1.atmos.temp.2005.12.clim.nc
# cafe.fcst.v1.atmos.temp.2006.1.clim.nc
# cafe.fcst.v1.atmos.temp.2006.2.clim.nc
# cafe.fcst.v1.atmos.temp.2006.3.clim.nc
# cafe.fcst.v1.atmos.temp.2006.4.clim.nc
# cafe.fcst.v1.atmos.temp.2006.5.clim.nc
# cafe.fcst.v1.atmos.temp.2006.6.clim.nc
# cafe.fcst.v1.atmos.temp.2006.7.clim.nc
# cafe.fcst.v1.atmos.temp.2006.8.clim.nc
# cafe.fcst.v1.atmos.temp.2006.9.clim.nc
# cafe.fcst.v1.atmos.temp.2006.10.clim.nc
# cafe.fcst.v1.atmos.temp.2006.11.clim.nc
# cafe.fcst.v1.atmos.temp.2006.12.clim.nc
# cafe.fcst.v1.atmos.temp.2007.1.clim.nc
# cafe.fcst.v1.atmos.temp.2007.2.clim.nc
# cafe.fcst.v1.atmos.temp.2007.3.clim.nc
# cafe.fcst.v1.atmos.temp.2007.4.clim.nc
# cafe.fcst.v1.atmos.temp.2007.5.clim.nc
# cafe.fcst.v1.atmos.temp.2007.6.clim.nc
# cafe.fcst.v1.atmos.temp.2007.7.clim.nc
# cafe.fcst.v1.atmos.temp.2007.8.clim.nc
# cafe.fcst.v1.atmos.temp.2007.9.clim.nc
# cafe.fcst.v1.atmos.temp.2007.10.clim.nc
# cafe.fcst.v1.atmos.temp.2007.11.clim.nc
# cafe.fcst.v1.atmos.temp.2007.12.clim.nc
# cafe.fcst.v1.atmos.temp.2008.1.clim.nc
# cafe.fcst.v1.atmos.temp.2008.2.clim.nc
# cafe.fcst.v1.atmos.temp.2008.3.clim.nc
# cafe.fcst.v1.atmos.temp.2008.4.clim.nc
# cafe.fcst.v1.atmos.temp.2008.5.clim.nc
# cafe.fcst.v1.atmos.temp.2008.6.clim.nc
# cafe.fcst.v1.atmos.temp.2008.7.clim.nc
# cafe.fcst.v1.atmos.temp.2008.8.clim.nc
# cafe.fcst.v1.atmos.temp.2008.9.clim.nc
# cafe.fcst.v1.atmos.temp.2008.10.clim.nc
# cafe.fcst.v1.atmos.temp.2008.11.clim.nc
# cafe.fcst.v1.atmos.temp.2008.12.clim.nc
# cafe.fcst.v1.atmos.temp.2009.1.clim.nc
# cafe.fcst.v1.atmos.temp.2009.2.clim.nc
# cafe.fcst.v1.atmos.temp.2009.3.clim.nc
# cafe.fcst.v1.atmos.temp.2009.4.clim.nc
# cafe.fcst.v1.atmos.temp.2009.5.clim.nc
# cafe.fcst.v1.atmos.temp.2009.6.clim.nc
# cafe.fcst.v1.atmos.temp.2009.7.clim.nc
# cafe.fcst.v1.atmos.temp.2009.8.clim.nc
# cafe.fcst.v1.atmos.temp.2009.9.clim.nc
# cafe.fcst.v1.atmos.temp.2009.10.clim.nc
# cafe.fcst.v1.atmos.temp.2009.11.clim.nc
# cafe.fcst.v1.atmos.temp.2009.12.clim.nc
# cafe.fcst.v1.atmos.temp.2010.2.clim.nc
# cafe.fcst.v1.atmos.temp.2010.3.clim.nc
# cafe.fcst.v1.atmos.temp.2010.4.clim.nc
# cafe.fcst.v1.atmos.temp.2010.5.clim.nc
# cafe.fcst.v1.atmos.temp.2010.6.clim.nc
# cafe.fcst.v1.atmos.temp.2010.7.clim.nc
# cafe.fcst.v1.atmos.temp.2010.8.clim.nc
# cafe.fcst.v1.atmos.temp.2010.9.clim.nc
# cafe.fcst.v1.atmos.temp.2010.10.clim.nc
# cafe.fcst.v1.atmos.temp.2010.11.clim.nc
# cafe.fcst.v1.atmos.temp.2010.12.clim.nc
# cafe.fcst.v1.atmos.temp.2011.1.clim.nc
# cafe.fcst.v1.atmos.temp.2011.2.clim.nc
# cafe.fcst.v1.atmos.temp.2011.3.clim.nc
# cafe.fcst.v1.atmos.temp.2011.4.clim.nc
# cafe.fcst.v1.atmos.temp.2011.5.clim.nc
# cafe.fcst.v1.atmos.temp.2011.6.clim.nc
# cafe.fcst.v1.atmos.temp.2011.7.clim.nc
# cafe.fcst.v1.atmos.temp.2011.8.clim.nc
# cafe.fcst.v1.atmos.temp.2011.9.clim.nc
# cafe.fcst.v1.atmos.temp.2011.10.clim.nc
# cafe.fcst.v1.atmos.temp.2011.11.clim.nc
# cafe.fcst.v1.atmos.temp.2011.12.clim.nc
# cafe.fcst.v1.atmos.temp.2012.1.clim.nc
# cafe.fcst.v1.atmos.temp.2012.2.clim.nc
# cafe.fcst.v1.atmos.temp.2012.3.clim.nc
# cafe.fcst.v1.atmos.temp.2012.4.clim.nc
# cafe.fcst.v1.atmos.temp.2012.5.clim.nc
# cafe.fcst.v1.atmos.temp.2012.6.clim.nc
# cafe.fcst.v1.atmos.temp.2012.7.clim.nc
# cafe.fcst.v1.atmos.temp.2012.8.clim.nc
# cafe.fcst.v1.atmos.temp.2012.9.clim.nc
# cafe.fcst.v1.atmos.temp.2012.10.clim.nc
# cafe.fcst.v1.atmos.temp.2012.11.clim.nc
# cafe.fcst.v1.atmos.temp.2012.12.clim.nc
# cafe.fcst.v1.atmos.temp.2013.1.clim.nc
# cafe.fcst.v1.atmos.temp.2013.2.clim.nc
# cafe.fcst.v1.atmos.temp.2013.3.clim.nc
# cafe.fcst.v1.atmos.temp.2013.4.clim.nc
# cafe.fcst.v1.atmos.temp.2013.5.clim.nc
# cafe.fcst.v1.atmos.temp.2013.6.clim.nc
# cafe.fcst.v1.atmos.temp.2013.7.clim.nc
# cafe.fcst.v1.atmos.temp.2013.8.clim.nc
# cafe.fcst.v1.atmos.temp.2013.9.clim.nc
# cafe.fcst.v1.atmos.temp.2013.10.clim.nc
# cafe.fcst.v1.atmos.temp.2013.11.clim.nc
# cafe.fcst.v1.atmos.temp.2013.12.clim.nc
# cafe.fcst.v1.atmos.temp.2014.1.clim.nc
# cafe.fcst.v1.atmos.temp.2014.2.clim.nc
# cafe.fcst.v1.atmos.temp.2014.3.clim.nc
# cafe.fcst.v1.atmos.temp.2014.4.clim.nc
# cafe.fcst.v1.atmos.temp.2014.5.clim.nc
# cafe.fcst.v1.atmos.temp.2014.6.clim.nc
# cafe.fcst.v1.atmos.temp.2014.7.clim.nc
# cafe.fcst.v1.atmos.temp.2014.8.clim.nc
# cafe.fcst.v1.atmos.temp.2014.9.clim.nc
# cafe.fcst.v1.atmos.temp.2014.10.clim.nc
# cafe.fcst.v1.atmos.temp.2014.11.clim.nc
# cafe.fcst.v1.atmos.temp.2014.12.clim.nc
# cafe.fcst.v1.atmos.temp.2015.1.clim.nc
# cafe.fcst.v1.atmos.temp.2015.2.clim.nc
# cafe.fcst.v1.atmos.temp.2015.3.clim.nc
# cafe.fcst.v1.atmos.temp.2015.4.clim.nc
# cafe.fcst.v1.atmos.temp.2015.6.clim.nc
# cafe.fcst.v1.atmos.temp.2015.8.clim.nc
# cafe.fcst.v1.atmos.temp.2015.9.clim.nc
# cafe.fcst.v1.atmos.temp.2015.10.clim.nc
# cafe.fcst.v1.atmos.temp.2015.11.clim.nc
# cafe.fcst.v1.atmos.temp.2015.12.clim.nc
# cafe.fcst.v1.atmos.temp.2016.1.clim.nc
# cafe.fcst.v1.atmos.temp.2016.2.clim.nc
# cafe.fcst.v1.atmos.temp.2016.3.clim.nc
# cafe.fcst.v1.atmos.temp.2016.4.clim.nc
# cafe.fcst.v1.atmos.temp.2016.5.clim.nc
# cafe.fcst.v1.atmos.temp.2016.6.clim.nc

# %%
numer = xr.concat(load_list,dim='run')['sum']
denom = xr.concat(load_list,dim='run')['count']

# %%
numer
# Out:
# <xarray.DataArray 'sum' (run: 165, time: 366, pfull: 24, lat: 90, lon: 144)>
# dask.array<shape=(165, 366, 24, 90, 144), dtype=float32, chunksize=(1, 366, 24, 90, 144)>
# Coordinates:
#   * time     (time) object '01-01' '01-02' '01-03' '01-04' '01-05' '01-06' ...
#   * lon      (lon) float64 1.25 3.75 6.25 8.75 11.25 13.75 16.25 18.75 21.25 ...
#   * lat      (lat) float64 -89.49 -87.98 -85.96 -83.93 -81.91 -79.89 -77.87 ...
#   * pfull    (pfull) float64 3.65 19.09 52.34 99.13 157.4 224.7 298.9 378.1 ...
# Dimensions without coordinates: run

# %%
denom
# Out:
# <xarray.DataArray 'count' (run: 165, time: 366)>
# dask.array<shape=(165, 366), dtype=float64, chunksize=(1, 366)>
# Coordinates:
#   * time     (time) object '01-01' '01-02' '01-03' '01-04' '01-05' '01-06' ...
# Dimensions without coordinates: run

# %%
numer.isel(run=10,pfull=23,time=205).plot()

# %%
numer = xr.concat(load_list,dim='run')['sum'].sum(dim='run')
denom = xr.concat(load_list,dim='run')['count'].sum(dim='run')

# %%
clim = (numer / denom).rename('temp')

# %%
clim_old = xr.open_dataset('/OSM/CBR/OA_DCFP/data/intermediate_products/pylatte_climatologies/cafe.fcst.v1.atmos_daily.1lev.2003010112_2021063012.clim.nc')
clim['time'] = clim_old['time']

# %%
clim.to_netcdf(path='/OSM/CBR/OA_DCFP/data/intermediate_products/pylatte_climatologies/cafe.fcst.v1.atmos.temp.clim.nc',
                                  mode = 'w')

# %%
clim_old['temp'] = clim

# %%
clim_old.to_netcdf('/OSM/CBR/OA_DCFP/data/intermediate_products/pylatte_climatologies/cafe.fcst.v1.atmos_daily.2003010112_2021063012.clim.nc')
